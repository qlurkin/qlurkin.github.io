# %%
import tensorflow as tf
# Out:
#  File "<ipython-input-1-64156d691fe5>", line 1, in <module>
#     import tensorflow as tf
#   File "C:\Users\qlurk\anaconda3\lib\site-packages\tensorflow\__init__.py", line 101, in <module>
#     from tensorflow_core import *
#   File "C:\Users\qlurk\anaconda3\lib\site-packages\tensorflow_core\__init__.py", line 40, in <module>
#     from tensorflow.python.tools import module_util as _module_util
#   File "C:\Users\qlurk\anaconda3\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\qlurk\anaconda3\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\qlurk\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\qlurk\anaconda3\lib\site-packages\tensorflow_core\python\__init__.py", line 49, in <module>
# ...

# %%
tf
